# %% [markdown]
#   # meta_step.04.MergeFile & SelectRepResult
#   ## - author:Xiao Nan
#   ## - begin date: 2024.3.12

# %%
import pandas as pd
from tqdm.notebook import tqdm
import os
import glob

# %% [markdown]
# ## 合并表格

# %%
folder_path = '../blast_info/blastp_result'
# all_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith('.csv')]
all_files = glob.glob(f'{folder_path}/*.csv')
print(type(all_files))
print(all_files[:10])
# all_files = all_files[:10]
# Out:
# <class 'list'>
# ['../blast_info/blastp_result/batch_123.csv', '../blast_info/blastp_result/batch_178.csv', '../blast_info/blastp_result/batch_27.csv', '../blast_info/blastp_result/batch_80.csv', '../blast_info/blastp_result/batch_81.csv', '../blast_info/blastp_result/batch_53.csv', '../blast_info/blastp_result/batch_150.csv', '../blast_info/blastp_result/batch_26.csv', '../blast_info/blastp_result/batch_204.csv', '../blast_info/blastp_result/batch_54.csv']

# %%
# 初始化一个列表来收集所有行的数据
data = []

# %%
for file_path in all_files:
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split(',')
            try:  # 使用try-except来避免转换错误
                qseqid = parts[0]
                sseqid = parts[-3]
                pident = float(parts[-2].strip())
                evalue = float(parts[-1])
                stitle = ','.join(parts[1:-3])  # 重新合并stitle部分
            except ValueError:
                print(f"Error converting line in file '{file_path}', line : {line}")
                continue
            # merged_df = merged_df.append({"qseqid": qseqid, "stitle": stitle, "sseqid": sseqid, "pident": pident, "evalue": evalue}, ignore_index=True)
            data.append([qseqid, stitle, sseqid, pident, evalue])
# Out:
# Error converting line in file '../blast_info/blastp_result/merged_blastp_results.csv', line : qseqid,stitle,sseqid,pident,evalue
#
# Error converting line in file '../blast_info/blastp_result/final_blastp_results.csv', line : qseqid,stitle,pident,evalue

# %%
# 一次性将列表转换为DataFrame
merged_df = pd.DataFrame(data, columns=["qseqid", "stitle", "sseqid", "pident", "evalue"])
merged_df.head()
# Out:
#                                               qseqid
# 0  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...  \
# 1  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 2  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 3  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 4  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
#
#                                               stitle               sseqid
# 0           cytochrome P450 [Actinospica acidiphila]  ref|WP_033274982.1|  \
# 1      MULTISPECIES: cytochrome P450 [Actinomycetes]  ref|WP_058915789.1|
# 2         cytochrome P450 [Streptomyces althioticus]      dbj|GGQ83487.1|
# 3        cytochrome P450 [Streptomyces griseorubens]      dbj|GGQ67939.1|
# 4  hypothetical protein DJ64_27525 [Streptomyces ...       gb|KEG43194.1|
#
#     pident  evalue
# 0  100.000     0.0
# 1   98.927     0.0
# 2   98.748     0.0
# 3   97.853     0.0
# 4   99.248     0.0

# %%
# 统计一下合并的后的结果
print(merged_df.shape)
unique_qseqid_count = merged_df['qseqid'].nunique()
print(f"unique_qseqid_count: {unique_qseqid_count}")
unique_stitles = merged_df['stitle'].unique()
print(f"unique_stitles_count: {len(unique_stitles)}") 
print(unique_stitles[:10])
# Out:
# (3408032, 5)
# unique_qseqid_count: 58250
# unique_stitles_count: 321418
# ['cytochrome P450 [Actinospica acidiphila]'
#  'MULTISPECIES: cytochrome P450 [Actinomycetes]'
#  'cytochrome P450 [Streptomyces althioticus]'
#  'cytochrome P450 [Streptomyces griseorubens]'
#  'hypothetical protein DJ64_27525 [Streptomyces griseorubens]'
#  'Cytochrome P450 [Streptomyces sp. di50b]'
#  'cytochrome P450 [Streptomyces sp. ZS0098]'
#  'cytochrome P450 [Streptomyces sp. BSE7-9]'
#  'cytochrome P450 [Streptomyces sp. OS603R]'
#  'LacI family DNA-binding transcriptional regulator [Streptomyces yerevanensis]']

# %%
# 存储合并后的CSV文件
merged_df.to_csv(f"{folder_path}/merged_blastp_results.csv", index=False)

# %%
# 筛选数据
filtered_df = merged_df[~merged_df['stitle'].str.contains('hypothetical|PREDICTED|putative', case=False)]
filtered_df = filtered_df[filtered_df['evalue'] <= 1e-5]
filtered_df = filtered_df[filtered_df['pident'] >= 70]

# %%
# 对筛选后的数据进行统计
print(filtered_df.shape)
filtered_unique_qseqid_count = filtered_df['qseqid'].nunique()
filtered_unique_stitles = filtered_df['stitle'].unique()
print(f"filtered_unique_qseqid_count: {filtered_unique_qseqid_count}")
print(f"filtered_unique_stitles_count: {len(filtered_unique_stitles)}")
print(filtered_unique_stitles[:10])
# Out:
# (925345, 5)
# filtered_unique_qseqid_count: 30444
# filtered_unique_stitles_count: 119683
# ['cytochrome P450 [Actinospica acidiphila]'
#  'MULTISPECIES: cytochrome P450 [Actinomycetes]'
#  'cytochrome P450 [Streptomyces althioticus]'
#  'cytochrome P450 [Streptomyces griseorubens]'
#  'Cytochrome P450 [Streptomyces sp. di50b]'
#  'cytochrome P450 [Streptomyces sp. ZS0098]'
#  'cytochrome P450 [Streptomyces sp. BSE7-9]'
#  'cytochrome P450 [Streptomyces sp. OS603R]'
#  'LacI family DNA-binding transcriptional regulator [Streptomyces yerevanensis]'
#  'LacI family DNA-binding transcriptional regulator [Streptomyces flaveus]']

# %%
filtered_df.head(20)
# Out:
#                                                qseqid
# 0   mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...  \
# 1   mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 2   mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 3   mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 5   mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 6   mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 7   mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 8   mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 9   mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 10  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 11  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 12  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 13  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 14  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 15  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 16  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 17  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 18  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 19  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_JN...
# 20  mG.blast.ref_prok_rep_genomes_150.fna.gz_NZ_CP...
#
#                                                stitle               sseqid
# 0            cytochrome P450 [Actinospica acidiphila]  ref|WP_033274982.1|  \
# 1       MULTISPECIES: cytochrome P450 [Actinomycetes]  ref|WP_058915789.1|
# 2          cytochrome P450 [Streptomyces althioticus]      dbj|GGQ83487.1|
# 3         cytochrome P450 [Streptomyces griseorubens]      dbj|GGQ67939.1|
# 5            Cytochrome P450 [Streptomyces sp. di50b]      emb|SCD97219.1|
# 6            cytochrome P450 [Actinospica acidiphila]  ref|WP_163085776.1|
# 7           cytochrome P450 [Streptomyces sp. ZS0098]  ref|WP_122215022.1|
# 8           cytochrome P450 [Streptomyces sp. BSE7-9]     gb|MBJ6647036.1|
# 9           cytochrome P450 [Streptomyces sp. OS603R]  ref|WP_279328235.1|
# 10  LacI family DNA-binding transcriptional regula...  ref|WP_033326341.1|
# 11  LacI family DNA-binding transcriptional regula...  ref|WP_246568034.1|
# 12  LacI family transcriptional regulator [Strepto...       gb|NGO10151.1|
# 13  LacI family transcriptional regulator [Strepto...       gb|NGO40724.1|
# 14  LacI family DNA-binding transcriptional regula...  ref|WP_206341014.1|
# 15  LacI family DNA-binding transcriptional regula...  ref|WP_225859186.1|
# 16  LacI family DNA-binding transcriptional regula...  ref|WP_094219915.1|
# 17  LacI family DNA-binding transcriptional regula...  ref|WP_097251658.1|
# 18  LacI family DNA-binding transcriptional regula...  ref|WP_123973047.1|
# 19  LacI family DNA-binding transcriptional regula...  ref|WP_245883346.1|
# 20  amidohydrolase family protein [Streptomyces de...  ref|WP_239750815.1|
#
#      pident  evalue
# 0   100.000     0.0
# 1    98.927     0.0
# 2    98.748     0.0
# 3    97.853     0.0
# 5    94.991     0.0
# 6    94.097     0.0
# 7    89.445     0.0
# 8    90.161     0.0
# 9    89.088     0.0
# 10  100.000     0.0
# 11   98.023     0.0
# 12   95.480     0.0
# 13   94.444     0.0
# 14   94.167     0.0
# 15   90.883     0.0
# 16   88.889     0.0
# 17   88.604     0.0
# 18   86.402     0.0
# 19   87.179     0.0
# 20  100.000     0.0

# %%
# 对每个qseqid只保留最优的行（evalue更小和pident更大）
final_df = filtered_df.sort_values(by=['qseqid', 'evalue', 'pident'], ascending=[True, True, False])
print(final_df.shape)
final_df.head(20)
# Out:
# (925345, 5)
#                                           qseqid
# 361701   known_Cas13a18_EreCas13a_WP_055061018.1  \
# 995183   known_Cas13a18_EreCas13a_WP_055061018.1
# 1628665  known_Cas13a18_EreCas13a_WP_055061018.1
# 2262147  known_Cas13a18_EreCas13a_WP_055061018.1
# 3015940  known_Cas13a18_EreCas13a_WP_055061018.1
# 121860   known_Cas13a21_LspCas13a_WP_021744063.1
# 755342   known_Cas13a21_LspCas13a_WP_021744063.1
# 1388824  known_Cas13a21_LspCas13a_WP_021744063.1
# 2022306  known_Cas13a21_LspCas13a_WP_021744063.1
# 2776099  known_Cas13a21_LspCas13a_WP_021744063.1
# 121861   known_Cas13a21_LspCas13a_WP_021744063.1
# 121862   known_Cas13a21_LspCas13a_WP_021744063.1
# 121863   known_Cas13a21_LspCas13a_WP_021744063.1
# 755343   known_Cas13a21_LspCas13a_WP_021744063.1
# 755344   known_Cas13a21_LspCas13a_WP_021744063.1
# 755345   known_Cas13a21_LspCas13a_WP_021744063.1
# 1388825  known_Cas13a21_LspCas13a_WP_021744063.1
# 1388826  known_Cas13a21_LspCas13a_WP_021744063.1
# 1388827  known_Cas13a21_LspCas13a_WP_021744063.1
# 2022307  known_Cas13a21_LspCas13a_WP_021744063.1
#
#                                                     stitle
# 361701   type VI-A CRISPR-associated RNA-guided ribonuc...  \
# 995183   type VI-A CRISPR-associated RNA-guided ribonuc...
# 1628665  type VI-A CRISPR-associated RNA-guided ribonuc...
# 2262147  type VI-A CRISPR-associated RNA-guided ribonuc...
# 3015940  type VI-A CRISPR-associated RNA-guided ribonuc...
# 121860   type VI-A CRISPR-associated RNA-guided ribonuc...
# 755342   type VI-A CRISPR-associated RNA-guided ribonuc...
# 1388824  type VI-A CRISPR-associated RNA-guided ribonuc...
# 2022306  type VI-A CRISPR-associated RNA-guided ribonuc...
# 2776099  type VI-A CRISPR-associated RNA-guided ribonuc...
# 121861   Crystal structure of RNP complex [Leptotrichia...
# 121862   type VI-A CRISPR-associated RNA-guided ribonuc...
# 121863   Chain A, CRISPR/Cas system Cas13a [Leptotrichi...
# 755343   Crystal structure of RNP complex [Leptotrichia...
# 755344   type VI-A CRISPR-associated RNA-guided ribonuc...
# 755345   Chain A, CRISPR/Cas system Cas13a [Leptotrichi...
# 1388825  Crystal structure of RNP complex [Leptotrichia...
# 1388826  type VI-A CRISPR-associated RNA-guided ribonuc...
# 1388827  Chain A, CRISPR/Cas system Cas13a [Leptotrichi...
# 2022307  Crystal structure of RNP complex [Leptotrichia...
#
#                       sseqid   pident  evalue
# 361701      gb|MCH3945239.1|   99.777     0.0
# 995183      gb|MCH3945239.1|   99.777     0.0
# 1628665     gb|MCH3945239.1|   99.777     0.0
# 2262147     gb|MCH3945239.1|   99.777     0.0
# 3015940     gb|MCH3945239.1|   99.777     0.0
# 121860   ref|WP_021744063.1|  100.000     0.0
# 755342   ref|WP_021744063.1|  100.000     0.0
# 1388824  ref|WP_021744063.1|  100.000     0.0
# 2022306  ref|WP_021744063.1|  100.000     0.0
# 2776099  ref|WP_021744063.1|  100.000     0.0
# 121861            pdb|5WTK|A   74.139     0.0
# 121862   ref|WP_018451595.1|   74.139     0.0
# 121863            pdb|7DMQ|A   74.139     0.0
# 755343            pdb|5WTK|A   74.139     0.0
# 755344   ref|WP_018451595.1|   74.139     0.0
# 755345            pdb|7DMQ|A   74.139     0.0
# 1388825           pdb|5WTK|A   74.139     0.0
# 1388826  ref|WP_018451595.1|   74.139     0.0
# 1388827           pdb|7DMQ|A   74.139     0.0
# 2022307           pdb|5WTK|A   74.139     0.0

# %%
final_df = final_df.drop_duplicates(subset=['qseqid'], keep='first')
print(final_df.shape)
final_df.head(20)
# Out:
# (30444, 5)
#                                                 qseqid
# 361701         known_Cas13a18_EreCas13a_WP_055061018.1  \
# 121860         known_Cas13a21_LspCas13a_WP_021744063.1
# 294746          known_Cas13a7_CgaCas13a_WP_034560163.1
# 599600          known_Cas13b8_PsaCas13b_WP_051522484.1
# 521980          known_Cas13c5_FpeCas13c_WP_027128616.1
# 101471                     known_Cas13d_WP_162611874.1
# 286130                     known_Cas13d_WP_286962119.1
# 599610                     known_Cas13d_WP_287925401.1
# 346591                     known_Cas13d_WP_287932746.1
# 538763  mG.JGI.100975_00.fna.gz_Ga0114922_10000010_137
# 294767  mG.JGI.100975_00.fna.gz_Ga0114922_10000010_139
# 313974   mG.JGI.100975_00.fna.gz_Ga0114922_10000065_32
# 361714   mG.JGI.100975_00.fna.gz_Ga0114922_10000065_45
# 121891   mG.JGI.100975_00.fna.gz_Ga0114922_10000103_43
# 101491   mG.JGI.100975_00.fna.gz_Ga0114922_10000103_44
# 599620    mG.JGI.100975_00.fna.gz_Ga0114922_10001267_3
# 538772   mG.JGI.100975_00.fna.gz_Ga0114922_10001523_15
# 313990    mG.JGI.100975_00.fna.gz_Ga0114922_10002752_6
# 59216     mG.JGI.100975_00.fna.gz_Ga0114922_10003906_9
# 59226            mG.JGI.101034.fna.gz_Ga0139030_128_17
#
#                                                    stitle
# 361701  type VI-A CRISPR-associated RNA-guided ribonuc...  \
# 121860  type VI-A CRISPR-associated RNA-guided ribonuc...
# 294746  type VI-A CRISPR-associated RNA-guided ribonuc...
# 599600  type VI-B CRISPR-associated RNA-guided ribonuc...
# 521980  type VI-C CRISPR-associated RNA-guided ribonuc...
# 101471  type VI-D CRISPR-associated RNA-guided ribonuc...
# 286130  type VI-D CRISPR-associated RNA-guided ribonuc...
# 599610  type VI-D CRISPR-associated RNA-guided ribonuc...
# 346591  type VI-D CRISPR-associated RNA-guided ribonuc...
# 538763  MAG: HDIG domain-containing protein [Armatimon...
# 294767  MAG: diacylglycerol kinase [Armatimonadota bac...
# 313974    DNA adenine methylase [Phycisphaerae bacterium]
# 361714  MAG: tetratricopeptide repeat protein [Plancto...
# 121891  glycosyltransferase family 4 protein [candidat...
# 101491  flippase-like domain-containing protein [candi...
# 599620        N-6 DNA methylase [Phycisphaerae bacterium]
# 538772  PQQ-binding-like beta-propeller repeat protein...
# 313990  MAG: ankyrin repeat domain-containing protein,...
# 59216   DNA topoisomerase IV subunit A [Phycisphaerale...
# 59226   competence protein CoiA family protein [Orenia...
#
#                      sseqid   pident         evalue
# 361701     gb|MCH3945239.1|   99.777   0.000000e+00
# 121860  ref|WP_021744063.1|  100.000   0.000000e+00
# 294746  ref|WP_034560163.1|  100.000   0.000000e+00
# 599600  ref|WP_025796877.1|   99.913   0.000000e+00
# 521980  ref|WP_027128616.1|  100.000   0.000000e+00
# 101471  ref|WP_162611874.1|  100.000   0.000000e+00
# 286130  ref|WP_286962119.1|  100.000   0.000000e+00
# 599610  ref|WP_287925401.1|  100.000   0.000000e+00
# 346591  ref|WP_287925401.1|  100.000   0.000000e+00
# 538763       gb|UCC67240.1|   72.578   0.000000e+00
# 294767       gb|UCC67238.1|   71.179   7.840000e-98
# 313974     gb|MDH4241780.1|   89.655   0.000000e+00
# 361714       gb|UCE99689.1|   70.320   0.000000e+00
# 121891     gb|MCD6163527.1|   72.900   0.000000e+00
# 101491     gb|MCD6163526.1|   72.205  2.810000e-175
# 599620     gb|MCK4341930.1|   70.481   0.000000e+00
# 538772      tpg|HIJ53473.1|  100.000   0.000000e+00
# 313990       gb|UCC99243.1|   73.611   2.800000e-58
# 59216      gb|MCC7292156.1|   80.739   0.000000e+00
# 59226   ref|WP_097019029.1|  100.000   0.000000e+00

# %%
# 输出最后的csv文件（只要：qseqid、stitle、pident、evalue四列）
final_df[['qseqid', 'stitle', 'pident', 'evalue']].to_csv(f"{folder_path}/final_blastp_results.csv", index=False)

# %%
# 打印统计结果，以供检查
print(f"Initial shape: {merged_df.shape}")
print(f"Filtered shape: {filtered_df.shape}")
print(f"Final shape: {final_df.shape}")
# Out:
# Initial shape: (3408032, 5)
# Filtered shape: (925345, 5)
# Final shape: (30444, 5)
